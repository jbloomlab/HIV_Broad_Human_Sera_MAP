# %% [markdown]
# This script speciffies which files FASTQ files should be concatenated into the a single fastq file per sample / read direction.
#
# This is ONLY for the HiSeq submitted on 200218.
# These are in the bloom_lab directory at: /shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/
#
#
# Note that I must sort the R1 and R2 samples such that they are in the same order (and will remained match to eahc other) when concatenating multiple files.

# %%
import os
import glob
import re
import subprocess

# %%
fastqdir = './FASTQ_files/'
if not os.path.isdir(fastqdir):
    os.mkdir(fastqdir)
os.chdir(fastqdir)

# %%
sample_directs = {}

# %%
# !pwd
# Out:
# /fh/fast/bloom_j/computational_notebooks/adingens/2020/BroadHumanSera_MAP/FASTQ_files

# %%
sample_directs["BG-M12b-IDC403-8500ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC403-8500ug_S22_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC403-8500ug_L2_S51_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-QA013-2282dpi-d25"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-QA013-2282dpi-d25_S12_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-QA013-2282dpi-d25_L2_S41_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-QA013-2282dpi-d40"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-QA013-2282dpi-d40_S13_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-QA013-2282dpi-d40_L2_S42_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-2-12-6ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-2-12-6ug_S16_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-2-12-6ug_L2_S45_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-561-IgG-2200ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-561-IgG-2200ug_S15_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-561-IgG-2200ug_L2_S44_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-561-IgG-2800ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-561-IgG-2800ug_S14_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-561-IgG-2800ug_L2_S43_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-mock"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-mock_S28_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-mock_L2_S57_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC0337-6000ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC0337-6000ug_S17_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC0337-6000ug_L2_S46_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC208-4000ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC208-4000ug_S27_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC208-4000ug_L2_S56_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC208-5000ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC208-5000ug_S26_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC208-5000ug_L2_S55_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC208-6000ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC208-6000ug_S25_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC208-6000ug_L2_S54_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC403-6000ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC403-6000ug_S24_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC403-6000ug_L2_S53_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC403-7500ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC403-7500ug_S23_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC403-7500ug_L2_S52_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC0337-4500ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC0337-4500ug_S18_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC0337-4500ug_L2_S47_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC0337-4000ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC0337-4000ug_S29_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC0337-4000ug_L2_S58_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC0136-8500ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC0136-8500ug_S19_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC0136-8500ug_L2_S48_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC0136-7000ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC0136-7000ug_S20_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC0136-7000ug_L2_S49_L002_R1_001.fastq.gz"]

sample_directs["BG-M12b-IDC0136-5500ug"] = ["/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC0136-5500ug_S21_L001_R1_001.fastq.gz",
                      "/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC0136-5500ug_L2_S50_L002_R1_001.fastq.gz"]

# %%
print(sample_directs.keys())
# Out:
# dict_keys(['BG-M12b-IDC403-8500ug', 'BG-M12b-QA013-2282dpi-d25', 'BG-M12b-QA013-2282dpi-d40', 'BG-M12b-2-12-6ug', 'BG-M12b-561-IgG-2200ug', 'BG-M12b-561-IgG-2800ug', 'BG-M12b-mock', 'BG-M12b-IDC0337-6000ug', 'BG-M12b-IDC208-4000ug', 'BG-M12b-IDC208-5000ug', 'BG-M12b-IDC208-6000ug', 'BG-M12b-IDC403-6000ug', 'BG-M12b-IDC403-7500ug', 'BG-M12b-IDC0337-4500ug', 'BG-M12b-IDC0337-4000ug', 'BG-M12b-IDC0136-8500ug', 'BG-M12b-IDC0136-7000ug', 'BG-M12b-IDC0136-5500ug'])

# %%
#iterate through samples 
for key in sample_directs:
    #dirlist = sample_directs[key]
    print("\n*********************")
    print ("\n parsing {0} files:".format(key))
    r1files = sample_directs[key]
    r2files = [w.replace('_R1_001.fastq.gz', '_R2_001.fastq.gz') for w in r1files]
    #r1files =[]
    #r2files = []
    #for direct in dirlist:
        
        #print("looking in {0}".format(direct))
        #dirr1files = glob.glob('{0}*R1*.fastq.gz'.format(direct))
        #for f in dirr1files:
        #    r1files.append(f)
        #dirr2files = glob.glob('{0}*R2*.fastq.gz'.format(direct))
        #for f2 in dirr2files:
        #    r2files.append(f2)
        
    assert len(r1files) == len(r2files)
    r1files.sort()
    r2files.sort()
    catf = '{0}_R1.fastq.gz'.format(key)
    if os.path.isfile(catf):
        print("\nConcatenated FASTQ file {0} already exists.".format(catf))
        print("\nFor this script, {0} would have been made by concatenating:\n\t{1}".format(
                catf, '\n\t'.join(r1files)))
    else:
        print("\n!!!!! \nCreating {0} by concatenating:\n\t{1}".format(
                catf, '\n\t'.join(r1files)))
        subprocess.check_call('zcat {0} | gzip > {1}'.format(
                ' '.join(r1files), catf), shell=True)
#now, do the same for R2 files
    catf2 = '{0}_R2.fastq.gz'.format(key)
    if os.path.isfile(catf2):
        print("\nConcatenated FASTQ file {0} already exists.".format(catf2))
        print("\nFor this script, {0} would have been made by concatenating:\n\t{1}".format(
                catf2, '\n\t'.join(r2files)))
    else:
        print("\nCreating {0} by concatenating:\n\t{1}".format(
                catf2, '\n\t'.join(r2files)))
        subprocess.check_call('zcat {0} | gzip > {1}'.format(
                ' '.join(r2files), catf2), shell=True)
# Out:
# *********************
#
#  parsing BG-M12b-IDC403-8500ug files:
#
# !!!!!
# Creating BG-M12b-IDC403-8500ug_R1.fastq.gz by concatenating:
# 	/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC403-8500ug_S22_L001_R1_001.fastq.gz
# 	/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC403-8500ug_L2_S51_L002_R1_001.fastq.gz
#
# Creating BG-M12b-IDC403-8500ug_R2.fastq.gz by concatenating:
# 	/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane1/BG-M12b-IDC403-8500ug_S22_L001_R2_001.fastq.gz
# 	/shared/ngs/illumina/bloom_lab/200218_D00300_0910_AHCHHJBCX3/Unaligned/Project_lane2/BG-M12b-IDC403-8500ug_L2_S51_L002_R2_001.fastq.gz
#
# *********************
#
#  parsing BG-M12b-QA013-2282dpi-d25 files:
#
# !!!!!
# Creating BG-M12b-QA013-2282dpi-d25_R1.fastq.gz by concatenating:
# ...
