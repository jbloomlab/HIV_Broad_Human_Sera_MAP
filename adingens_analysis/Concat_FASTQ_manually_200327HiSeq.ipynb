# %% [markdown]
# This script speciffies which files FASTQ files should be concatenated into the a single fastq file per sample / read direction.
#
# This is ONLY for the HiSeq submitted on 200218.
# These are in the bloom_lab directory at: /shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab
#
#
# Note that I must sort the R1 and R2 samples such that they are in the same order (and will remained match to eahc other) when concatenating multiple files.

# %%
import os
import glob
import re
import subprocess

# %%
fastqdir = './FASTQ_files/'
if not os.path.isdir(fastqdir):
    os.mkdir(fastqdir)
os.chdir(fastqdir)

# %%
sample_directs = {}

# %%
# !pwd
# Out:
# /fh/fast/bloom_j/computational_notebooks/adingens/2020/BroadHumanSera_MAP/FASTQ_files

# %%
#macaque sera
#sample_directs["BG-M32a-33203-4000ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-33203-4000ug/BG-M32a-33203-4000ug_AAACATCG_L001_R1_001.fastq.gz"]

#sample_directs["M32a-33311-250ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-33311-250ug/BG-M32a-33311-250ug_CAGATCTG_L001_R1_001.fastq.gz"]

#sample_directs["BG-M32a-33311-650ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-33311-650ug/BG-M32a-33311-650ug_ACATTGGC_L001_R1_001.fastq.gz"]

#sample_directs["BG-M32a-33433-3500ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-33433-3500ug/BG-M32a-33433-3500ug_CATCAAGT_L001_R1_001.fastq.gz",
#                                         "/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-33433-3500ug/BG-M32a-33433-3500ug_CATCAAGT_L001_R1_002.fastq.gz"]

#sample_directs["BG-M32a-34945-4000ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-34945-4000ug/BG-M32a-34945-4000ug_AACGTGAT_L001_R1_001.fastq.gz"]

#sample_directs["BG-M32a-CG41-300ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-CG41-300ug/BG-M32a-CG41-300ug_ACCACTGT_L001_R1_001.fastq.gz"]

#sample_directs["BG-M32a-CG41-650ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-CG41-650ug/BG-M32a-CG41-650ug_AGTGGTCA_L001_R1_001.fastq.gz"]

#sample_directs["BG-M32a-MA225-4000ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-MA225-4000ug/BG-M32a-MA225-4000ug_ATGCCTAA_L001_R1_001.fastq.gz"]


#mock
sample_directs["BG-M32a-mock"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-mock/BG-M32a-mock_ACCTCCAA_L001_R1_001.fastq.gz"]

#broad human sera
sample_directs["BG-M32a-IDC0191-6000ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDC0191-6000ug/BG-M32a-IDC0191-6000ug_AACGCTTA_L001_R1_001.fastq.gz"]

sample_directs["BG-M32a-IDC0245-8000ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDC0245-8000ug/BG-M32a-IDC0245-8000ug_AACCGAGA_L001_R1_001.fastq.gz"]

sample_directs["BG-M32a-IDC0396-9000ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDC0396-9000ug/BG-M32a-IDC0396-9000ug_CGCTGATC_L001_R1_001.fastq.gz",
                                           "/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDC0396-9000ug/BG-M32a-IDC0396-9000ug_CGCTGATC_L001_R1_002.fastq.gz"]
                                                                                                                                                                                        #IDC0396-9000ug_CGCTGATC_L001_R2_001.fastq.gz
sample_directs["BG-M32a-IDC0513-5000ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDC0513-5000ug/BG-M32a-IDC0513-5000ug_CTGTAGCC_L001_R1_001.fastq.gz",
                                           "/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDC0513-5000ug/BG-M32a-IDC0513-5000ug_CTGTAGCC_L001_R1_002.fastq.gz"]

sample_directs["BG-M32a-IDC0518-8000ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDC0518-8000ug/BG-M32a-IDC0518-8000ug_AGTACAAG_L001_R1_001.fastq.gz"]

sample_directs["BG-M32a-IDC0546-8500ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDC0546-8500ug/BG-M32a-IDC0546-8500ug_AACAACCA_L001_R1_001.fastq.gz",
                                           "/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDC0546-8500ug/BG-M32a-IDC0546-8500ug_AACAACCA_L001_R1_002.fastq.gz"]

sample_directs["BG-M32a-IDF033-1400ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDF033-1400ug/BG-M32a-IDF033-1400ug_AAGACGGA_L001_R1_001.fastq.gz"]

sample_directs["BG-M32a-IDF033-1800ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDF033-1800ug/BG-M32a-IDF033-1800ug_ACAAGCTA_L001_R1_001.fastq.gz",
                                          "/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDF033-1800ug/BG-M32a-IDF033-1800ug_ACAAGCTA_L001_R1_002.fastq.gz"]

sample_directs["BG-M32a-IDF065-1400ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDF065-1400ug/BG-M32a-IDF065-1400ug_AAGGTACA_L001_R1_001.fastq.gz"]

sample_directs["BG-M32a-IDF141-6000ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDF141-6000ug/BG-M32a-IDF141-6000ug_ACAGCAGA_L001_R1_001.fastq.gz",
                                          "/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDF141-6000ug/BG-M32a-IDF141-6000ug_ACAGCAGA_L001_R1_002.fastq.gz"]

sample_directs["BG-M32a-IDF147-5300ug"] = ["/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDF147-5300ug/BG-M32a-IDF147-5300ug_ACACAGAA_L001_R1_001.fastq.gz"]

# %%
print(sample_directs.keys())
# Out:
# dict_keys(['BG-M32a-mock', 'BG-M32a-IDC0191-6000ug', 'BG-M32a-IDC0245-8000ug', 'BG-M32a-IDC0396-9000ug', 'BG-M32a-IDC0513-5000ug', 'BG-M32a-IDC0518-8000ug', 'BG-M32a-IDC0546-8500ug', 'BG-M32a-IDF033-1400ug', 'BG-M32a-IDF033-1800ug', 'BG-M32a-IDF065-1400ug', 'BG-M32a-IDF141-6000ug', 'BG-M32a-IDF147-5300ug'])

# %%
#iterate through samples 
for key in sample_directs:
    #dirlist = sample_directs[key]
    print("\n*********************")
    print ("\n parsing {0} files:".format(key))
    r1files = sample_directs[key]
    r2files = [w.replace('_R1_001.fastq.gz', '_R2_001.fastq.gz').replace('_R1_002.fastq.gz', '_R2_002.fastq.gz') for w in r1files]
    #r1files =[]
    #r2files = []
    #for direct in dirlist:
        
        #print("looking in {0}".format(direct))
        #dirr1files = glob.glob('{0}*R1*.fastq.gz'.format(direct))
        #for f in dirr1files:
        #    r1files.append(f)
        #dirr2files = glob.glob('{0}*R2*.fastq.gz'.format(direct))
        #for f2 in dirr2files:
        #    r2files.append(f2)
        
    assert len(r1files) == len(r2files)
    r1files.sort()
    r2files.sort()
    catf = '{0}_R1.fastq.gz'.format(key)
    if os.path.isfile(catf):
        print("\nConcatenated FASTQ file {0} already exists.".format(catf))
        print("\nFor this script, {0} would have been made by concatenating:\n\t{1}".format(
                catf, '\n\t'.join(r1files)))
    else:
        print("\n!!!!! \nCreating {0} by concatenating:\n\t{1}".format(
                catf, '\n\t'.join(r1files)))
        subprocess.check_call('zcat {0} | gzip > {1}'.format(
                ' '.join(r1files), catf), shell=True)
#now, do the same for R2 files
    catf2 = '{0}_R2.fastq.gz'.format(key)
    if os.path.isfile(catf2):
        print("\nConcatenated FASTQ file {0} already exists.".format(catf2))
        print("\nFor this script, {0} would have been made by concatenating:\n\t{1}".format(
                catf2, '\n\t'.join(r2files)))
    else:
        print("\nCreating {0} by concatenating:\n\t{1}".format(
                catf2, '\n\t'.join(r2files)))
        subprocess.check_call('zcat {0} | gzip > {1}'.format(
                ' '.join(r2files), catf2), shell=True)
# Out:
# *********************
#
#  parsing BG-M32a-mock files:
#
# !!!!!
# Creating BG-M32a-mock_R1.fastq.gz by concatenating:
# 	/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-mock/BG-M32a-mock_ACCTCCAA_L001_R1_001.fastq.gz
#
# Creating BG-M32a-mock_R2.fastq.gz by concatenating:
# 	/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-mock/BG-M32a-mock_ACCTCCAA_L001_R2_001.fastq.gz
#
# *********************
#
#  parsing BG-M32a-IDC0191-6000ug files:
#
# !!!!!
# Creating BG-M32a-IDC0191-6000ug_R1.fastq.gz by concatenating:
# 	/shared/ngs/illumina/bloom_lab/200327_D00300_0943_AHF3KHBCX3/Unaligned/Project_bloom_lab/Sample_BG-M32a-IDC0191-6000ug/BG-M32a-IDC0191-6000ug_AACGCTTA_L001_R1_001.fastq.gz
#
# Creating BG-M32a-IDC0191-6000ug_R2.fastq.gz by concatenating:
# ...
